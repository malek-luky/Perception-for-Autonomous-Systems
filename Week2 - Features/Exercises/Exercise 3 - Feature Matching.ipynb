# %% [markdown]
# # Feature Description and Matching
# ## SIFT
#
# Import the packages and load the image "Book.jpg"

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread("Book.jpg")

b,g,r = cv2.split(img) # Changing the order from bgr to rgb so that matplotlib can show it
img = cv2.merge([r,g,b])
plt.imshow(img)

# %% [markdown]
# We'll start by converting the image to grayscale.

# %%
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
plt.imshow(gray, cmap = 'gray')

# %% [markdown]
# Now we will attempt to find the features and descriptors using [SIFT](https://docs.opencv.org/2.4/modules/nonfree/doc/feature_detection.html). (algorithm by D. Lowe) In OpenCV we will do it by first creating a SIFT object and then use the detectAndCompute function.

# %%
sift = cv2.xfeatures2d.SIFT_create()  # Need to run with anaconda (base) python!
kp, des = sift.detectAndCompute(gray, None) #Keypoints and descriptors

# %% [markdown]
# To show the detected keypoints we use the function [drawKeyPoints](https://docs.opencv.org/master/d4/d5d/group__features2d__draw.html#ga5d2bafe8c1c45289bc3403a40fb88920). We scale the picture up a bit using "figsize", so it's easier to see.

# %%
kp_img = cv2.drawKeypoints(gray, kp, img, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
plt.figure(figsize = (10,10))
plt.imshow(kp_img)

# %% [markdown]
# Let's load the image "More_books.jpg" and convert it to grayscale.

# %%
img2 = cv2.imread("More_books.jpg")
b,g,r = cv2.split(img2) # Changing the order from bgr to rgb so that matplotlib can show it
img2 = cv2.merge([r,g,b])

gray2 = cv2.cvtColor(img2, cv2.COLOR_RGB2GRAY)
plt.imshow(gray2, cmap = 'gray')

# %% [markdown]
# Now we use the same SIFT method to find the keypoints and descriptors of this image.

# %%
kp2, des2 = sift.detectAndCompute(gray2, None)

# %% [markdown]
# Now that we have the descriptors of both images, let's see if we can match them and find the book from the first image in the second image.
# For this example we use Brute Force Matcher ([cv2.BFMatcher](https://docs.opencv.org/master/d3/da1/classcv_1_1BFMatcher.html)). We use the function cv2.match to find the matches.

# %%
bf = cv2.BFMatcher()
matches = bf.match(des, des2)

# %% [markdown]
# We use the function [cv2.drawMatches](https://docs.opencv.org/3.4/d4/d5d/group__features2d__draw.html) to display the result. We'd like to display the best of the matches. The matching is made using a distance measurement between the descriptors, the smaller the distance, the better the match. So we sort the "matches" array using the distance term and then we plot only the first 100 matches.

# %%
matches = sorted(matches, key = lambda x:x.distance)

img3 = cv2.drawMatches(gray,kp,gray2,kp2,matches[:100],None,flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)

plt.figure(figsize = (20,20))
plt.imshow(img3)

# %% [markdown]
# We see that most of the matches are correct, but with some outliers.

# %% [markdown]
# # Exercise 3
# Using the same two images, try to use ORB(https://docs.opencv.org/3.4/d1/d89/tutorial_py_orb.html) instead of SIFT to find the keypoints and the descriptors. Does one of these methods give a better result than the other? Try plotting more than just the 100 matches and see if there is a difference between the two methods.

# %% [markdown]
# Loading first picture:

# %%
img = cv2.imread("Book.jpg", 0) #'0' flag is immediately for grascale and we dont need

# %% [markdown]
# Using ORB on first pic:

# %%
orb = cv2.ORB_create() #initialize ORB detector
kp = orb.detect(img, None) #find keypoints with ORB
kp, des = orb.compute(img, kp) #compute descriptors
kp_img = cv2.drawKeypoints(img, kp, None, color=(255, 0, 0), flags=0)
plt.imshow(kp_img)

# %% [markdown]
# Doing exactly the same with the second image:

# %%
img2 = cv2.imread("More_books.jpg", 0)

# %% [markdown]
# Using ORB on second Image

# %%
orb2 = cv2.ORB_create() #initialize ORB detector
kp2 = orb2.detect(img2, None) #find keypoints with ORB
kp2, des2 = orb2.compute(img2, kp2) #compute descriptors
kp_img2 = cv2.drawKeypoints(img2, kp2, None, color=(255, 0, 0), flags=0)
plt.imshow(kp_img2)

# %% [markdown]
# Matching keypoints together:

# %%
bf = cv2.BFMatcher()
matches = bf.match(des, des2)

#Show it together with matching lines:
matches = sorted(matches, key = lambda x:x.distance)

img3 = cv2.drawMatches(gray,kp,gray2,kp2,matches[:100],None,flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)

plt.figure(figsize = (20,20))
plt.imshow(img3)

print('Though in our case orb seems have more matches on the text from the book cover, its not typical as program still sees just pixels, not text')
# Out:
# Though in our case orb seems have more matches on the text from the book cover, its not typical as program still sees just pixels, not text
